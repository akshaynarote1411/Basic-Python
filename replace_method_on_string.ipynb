# %%
str1="ola ola ola"

# %%
#str1.replace(old, new, count=-1, /)    It is use to replace the old substring by the given new substring 

str1.replace('l','L')
# Out:
# 'oLa oLa oLa'

# %%
str1.replace("l","L",1)
# Out:
# 'oLa ola ola'

# %%
str1.replace("l","L",2)
# Out:
# 'oLa oLa ola'

# %%
str1.replace("z","Z")   # If the substring is not found, it will not gives error it will print the main string as it is.
# Out:
# 'ola ola ola'

# %%
 # Replacing 2nd "l" with "L"

# %%
i1 = str1.index("l")
i2 = str1.index("l",i1+1)
print(i1,"|",i2)
# Out:
# 1 | 5

# %%
s2 = str1[:i2]
s3 = str1[i2:]
print(s2,"|",s3)
# Out:
# ola o | la ola

# %%
s4 = s3.replace("l","L",1)
s4
# Out:
# 'La ola'

# %%
s5 = s2 + s4
print(s5)
# Out:
# ola oLa ola

# %%
str1.startswith("o")
# Out:
# True
