# %%
h1 = '''Hello world'''

# %%
print(h1)
# Out:
# Hello world

# %%
a = 10
name = 'Ram'

# %%
print(f"My number is {a} and My name is {name}")
# Out:
# My number is 10 and My name is Ram

# %%
print("My number is {} and My name is {}".format(a,name))
# Out:
# My number is 10 and My name is Ram

# %%
print("My number is",a,"and My name is",name)
# Out:
# My number is 10 and My name is Ram

# %%
# Above all types output is same just ways are differnt
