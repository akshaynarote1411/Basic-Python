# %%
s1 = "hi how are you"
s1.startswith("h")
# Out:
# True

# %%
s1.startswith("H")
# Out:
# False

# %%
s1.startswith("hi")
# Out:
# True

# %%
s1.startswith(s1)
# Out:
# True

# %%
s1.startswith("hi ")
# Out:
# True

# %%
s1.endswith("u")
# Out:
# True

# %%
s1.endswith("you")
# Out:
# True

# %%
s1.endswith("r")
# Out:
# False

# %%
s1.endswith("e you")
# Out:
# True

# %%
s1.endswith(s1)
# Out:
# True
