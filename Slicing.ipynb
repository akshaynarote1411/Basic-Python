# %%
str1 = "hai how are you"
len(str1)
# Out:
# 15

# %%
str1[20]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 str1[20]
#
# IndexError: string index out of range

# %%
# While slicing we can get same answer by two ways 
# 1. By giving direct positive start and end  ex. str1[1:10:1]
# 2. By giving negative start and end ex. str1[-14:-5:1]
str1[1:10:1]
# Out:
# 'ai how ar'

# %%
str1[-14:-5:1]
# Out:
# 'ai how ar'

# %%
str1[1:4]
# Out:
# 'ai '

# %%
str1[4:-1]
# Out:
# 'how are yo'

# %%
str1[2:10:2]
# Out:
# 'ihwa'

# %%
str1[-10:-1]
# Out:
# 'ow are yo'

# %%
str1[1:10:-1]
# Out:
# ''

# %%
str1[10:1:-1]
# Out:
# 'era woh i'

# %%
str1[:4]
# Out:
# 'hai '

# %%
str1[4:]
# Out:
# 'how are you'

# %%
str1[-10::-1]
# Out:
# 'oh iah'

# %%
str1[3:-3:1]
# Out:
# ' how are '

# %%
str1[2:-6:1]
# Out:
# 'i how a'

# %%
str1[10:2:-1]
# Out:
# 'era woh '

# %%
str1[10:-10:-1]
# Out:
# 'era w'

# %%
str1[12:-6:-1]
# Out:
# 'y e'

# %%
str1[10:-12:1]
# Out:
# ''

# %%
str1[-4:15:-1]   # Empty answer means not possible
# Out:
# ''

# %% [markdown]
# #### Special case

# %%
str1[2:50]
# Out:
# 'i how are you'

# %%
# But above case is not possible in for loop it will gives error(index out off range) after string lenght output completed

for i in range(2,50):
    print(str1[i])
# Out:
# i
#
# h
# o
# w
#
# a
# r
# e
#
# y
# o
# u
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[37], line 4
#       1 # But above case is not possible in for loop it will gives error after string lenght output completed
#       3 for i in range(2,50):
# ----> 4     print(str1[i])
#
# IndexError: string index out of range

# %%
str1[::]
# Out:
# 'hai how are you'

# %%
str1[::-1]
# Out:
# 'uoy era woh iah'

# %%
str1[1::1]
# Out:
# 'ai how are you'

# %%
str1[:9:1]
# Out:
# 'hai how a'

# %%
str1[:-10:-1]
# Out:
# 'uoy era w'

# %%
str1[-2::-1]
# Out:
# 'oy era woh iah'
