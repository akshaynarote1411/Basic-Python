# %%
l=[1,2,3,4,5,6]
l[-4:-1]
# Out:
# [3, 4, 5]

# %%
l[-1:-4]        # If the indexes passe in reverse direction then slicing will not happen , it will give empty list
# Out:
# []

# %%
l[-1:-2]
# Out:
# []

# %%
l[-1]
# Out:
# 6

# %%
l[-1:2]
# Out:
# []

# %%
l[-5:4]
# Out:
# [2, 3, 4]

# %%
l[-5:-1]
# Out:
# [2, 3, 4, 5]

# %%
l[-6:-1:2]
# Out:
# [1, 3, 5]

# %%
l[-6:-1:-1]     # Reverse Slicing will not possible(negative steps are not possible), it will give empty list
# Out:
# []

# %%
l[1:5:-2]
# Out:
# []
