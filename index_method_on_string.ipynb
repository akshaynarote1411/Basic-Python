# %%
str1 = "ola ola ola"

# %%
# str1.index(sub,start,end)  # It will gives the index number of the passing substring in the string from start to end bydefault start=0, end=-1
str1.index('a')
# Out:
# 2

# %%
str1.index("a",4)
# Out:
# 6

# %%
str1.index("a",3,5) # If the substring is not found then it will gives error substring not found.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 str1.index("a",3,5)
#
# ValueError: substring not found

# %%
str1.index("ol")
# Out:
# 0

# %%
str1.index(" l")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 str1.index(" l")
#
# ValueError: substring not found

# %%
str1.index(" o")
# Out:
# 3

# %%
str1.index(" ol",4,10)
# Out:
# 7
