# %%
a = [20,30]
b = 10

c = a.copy()
print(c)
# Out:
# [20, 30]

# %%
c.append(11)
c
# Out:
# [20, 30, 11]

# %%
a
# Out:
# [20, 30]

# %%
s = {'srk',10,20.1}

s.add(2)
s
# Out:
# {10, 2, 20.1, 'srk'}

# %%
copy = s.copy()

# %%
copy.add(22)
copy
# Out:
# {10, 2, 20.1, 22, 'srk'}

# %%
s
# Out:
# {10, 2, 20.1, 'srk'}
