# %%
str1 = "ola ola ola"

# %%
# str1.find(sub,start,end)  # It will gives the index number of the passing substring in the string from start to end bydefault start=0, end=-1
str1.find('s')              # If the substring not found it will not gives error, it will gives -1 as output.
# Out:
# -1

# %%
str1.index("a",4)
# Out:
# 6

# %%
str1.find("a",4)
# Out:
# 6

# %%
str1.index("a",3,5) # If the substring is not found then it will gives error substring not found.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 str1.index("a",3,5)
#
# ValueError: substring not found

# %%
str1.find("a",3,5) # If the substring is not found then it will not gives error, It will gives -1.
# Out:
# -1
