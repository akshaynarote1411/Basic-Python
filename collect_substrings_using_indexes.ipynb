# %%
s1 = "virat.kohli@rcb.com"
s2 = "rohit.sharma@mi.com"

# %%
i1 = s1.index(".")
i1
# Out:
# 5

# %%
i2 = s1.index("@")
i2
# Out:
# 11

# %%
i3 = s1.index(".",i1+1)
i3
# Out:
# 15

# %%
s1[:i1],s1[i1+1:i2],s1[i2+1:i3]
# Out:
# ('virat', 'kohli', 'rcb')

# %%
i1 = s2.index(".")
i1
# Out:
# 5

# %%
i2 = s2.index("@")
i2
# Out:
# 12

# %%
i3 = s2.index(".",i1+1)
i3
# Out:
# 15

# %%
s2[:i1],s2[i1+1:i2],s2[i2+1:i3]
# Out:
# ('rohit', 'sharma', 'mi')
