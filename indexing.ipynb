# %%
l = ['a','b','c',1,2,3,"a"]

# %%
l[1]
# Out:
# 'b'

# %%
l[1:4]
# Out:
# ['b', 'c', 1]

# %%
l[::2]
# Out:
# ['a', 'c', 2, 'a']

# %%
l1 = [1,2,3,4,"a","c",["b","d"]]

# %%
l1[1]
# Out:
# 2

# %%
l1[4:7]
# Out:
# ['a', 'c', ['b', 'd']]

# %%
l1[6][0]
# Out:
# 'b'

# %%
l1[6][1]
# Out:
# 'd'

# %%
l2=["e","f",1,3,55,[1,33,"t"],["21a",44]]

# %%
l2[4:6]
# Out:
# [55, [1, 33, 't']]

# %%
l2[6][1]
# Out:
# 44

# %%
l2[5][2]
# Out:
# 't'

# %%
l3=[1,[2,"3",3.3],[2,["2a","e"]]]

# %%
l3[1]
# Out:
# [2, '3', 3.3]

# %%
l3[1][2]
# Out:
# 3.3

# %%
l3[2]
# Out:
# [2, ['2a', 'e']]

# %%
l3[2][1]
# Out:
# ['2a', 'e']

# %%
l3[2][1][1]
# Out:
# 'e'

# %%
l4 = ["fruit",["orange",["MH",['Shivaji',["Shambhaji",["chavva"],["vicky"]]]]]]

# extract "vicky"

l4[1]
# Out:
# ['orange', ['MH', ['Shivaji', ['Shambhaji', ['chavva'], ['vicky']]]]]

# %%
l4[1][1]
# Out:
# ['MH', ['Shivaji', ['Shambhaji', ['chavva'], ['vicky']]]]

# %%
l4[1][1][0]
# Out:
# 'MH'

# %%
l4[1][1][1][0]
# Out:
# 'Shivaji'

# %%
l4[1][1][1][1][1][0]
# Out:
# 'chavva'
